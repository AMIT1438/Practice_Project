# %%
#importing or including important libraries
import pandas as pd
import numpy as np

# %%
#reading the csv file in a data set
ds = pd.read_csv('bigdatamart_Train.csv')

#storing the data set in a data frame
df = pd.DataFrame(data=ds)

#displaying the data frame
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#reading the csv file in a data set
dstest = pd.read_csv('bigdatamart_Test.csv')

#storing the data set in a data frame
dftest = pd.DataFrame(data=ds)

#displaying the data frame
dftest
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#printing the the type of data frame
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#printing the columns available in data frame
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
#displaying the type of data frame columns
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
#displaying the top 5 rows of data frame
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
#displaying the bottom 5 rows of data frame
df.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
#displaying sample row of the data frame
df.sample(5)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7024           FDS01        11.60          Low Fat         0.017817
# 6731           NCX29        10.00          Low Fat         0.089153
# 1574           NCV30        20.20          Low Fat         0.066201
# 6586           FDD57        18.10          Low Fat         0.022526
# 6299           FDS36         8.38          Regular         0.046960
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7024                 Canned  177.0686            OUT018
# 6731     Health and Hygiene  147.7102            OUT046
# 1574              Household   61.4510            OUT018
# 6586  Fruits and Vegetables   95.0094            OUT017
# 6299           Baking Goods  111.8570            OUT049
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 7024                       2009      Medium               Tier 3
# 6731                       1997       Small               Tier 1
# ...

# %% [markdown]
# # Null Values

# %%
#displaying boolean (T/F) for the values if it is null or not null
df.isnull()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False        False             False            False
# ...               ...          ...               ...              ...
# 8518            False        False             False            False
# 8519            False        False             False            False
# 8520            False        False             False            False
# 8521            False        False             False            False
# 8522            False        False             False            False
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
#displaying the total number of Null Values available columnwise
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#displaying the total number of Null Values available in the entire data frame
df.isnull().sum().sum()
# Out:
# 3873

# %%
#displaying the shape of dataset i.e. rows and columns present in the dataset
df.shape
# Out:
# (8523, 12)

# %% [markdown]
# ##### since there are null values are present in Item_Weight and Outlet_Size so we need to fill these values

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
#Replacing null values with mean values of the column
df['Item_Weight'].fillna(df['Item_Weight'].mean(),inplace=True)

# %%
df['Outlet_Size'].mode()
# Out:
# 0    Medium
# dtype: object

# %%
#Replacing null values with mode values of the column since it is string type
df['Outlet_Size'].fillna('Medium',inplace=True)
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
#Since Machine understand only numeric values and we need to convert string values to numeric
#But we don't have any string value features

# %%
#showing unique values 
df['Outlet_Size'].unique()
# Out:
# array(['Medium', 'High', 'Small'], dtype=object)

# %%
#showing unique values 
df['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
#showing unique values 
df['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %% [markdown]
# #### Encoding of Data

# %%
#Encode the categorical data in int format to be used by Machine Learning
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

for i in df.columns:
    if(df.dtypes[i]=='O'):
        df[i]=le.fit_transform(df[i])

df
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156        9.300                 1         0.016047
# 1                   8        5.920                 2         0.019278
# 2                 662       17.500                 1         0.016760
# 3                1121       19.200                 2         0.000000
# 4                1297        8.930                 1         0.000000
# ...               ...          ...               ...              ...
# 8518              370        6.865                 1         0.056783
# 8519              897        8.380                 2         0.046982
# 8520             1357       10.600                 1         0.035186
# 8521              681        7.210                 2         0.145221
# 8522               50       14.800                 1         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
#Checking null values by showing it on heatmap, There is no null values in dataframe now
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show()

# %% [markdown]
# # EDA

# %% [markdown]
# ## Scatterplot

# %%
#importing seaborn library as sns
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.scatterplot(x="Item_Outlet_Sales", y="Item_Weight", data=df)
plt.show()

# %% [markdown]
# - Showing sales data with relation to weight

# %%
sns.scatterplot(x="Item_Outlet_Sales", y="Item_MRP", data=df)
plt.show()

# %% [markdown]
# - As the item price increases the sales figure also gets increased and number of items sold are also increased

# %%
#showing data of all the columns
import matplotlib.pyplot as plt
sns.pairplot(df)
plt.savefig('mypair.png')
plt.show()

# %% [markdown]
# - Showing how the values in different columns are spread

# %%
#showing correlation
df.corr()
# Out:
#                            Item_Identifier  Item_Weight  Item_Fat_Content  \
# Item_Identifier                   1.000000     0.044518         -0.098114
# Item_Weight                       0.044518     1.000000         -0.017331
# Item_Fat_Content                 -0.098114    -0.017331          1.000000
# Item_Visibility                  -0.025482    -0.012049          0.034042
# Item_Type                        -0.017973     0.028015         -0.115958
# Item_MRP                          0.012853     0.024756         -0.000876
# Outlet_Identifier                -0.008602    -0.007975         -0.002357
# Outlet_Establishment_Year        -0.012772    -0.008301         -0.000189
# Outlet_Size                       0.001389    -0.007225         -0.012058
# Outlet_Location_Type              0.003656     0.004088         -0.004102
# Outlet_Type                      -0.001178    -0.000566         -0.004214
# Item_Outlet_Sales                 0.002869     0.011550          0.009800
#
# ...

# %%
#size of the figure
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,linecolor="black",fmt='.2f')
plt.show()

# %% [markdown]
# - 1. Item_MRP is highly correlated with item_outlet_sales with 57%
# - 2. Outlet_type is also substantially correlated with item_outlet_sales with 40%
# - 3. Other features are not subtantially correlated with item_outlet_sales

# %%
#showing the correlation of Happiness Score with other columns in sorted order
df.corr()['Item_Outlet_Sales'].sort_values()
# Out:
# Item_Visibility             -0.128625
# Outlet_Size                 -0.086182
# Outlet_Establishment_Year   -0.049135
# Item_Identifier              0.002869
# Item_Fat_Content             0.009800
# Item_Weight                  0.011550
# Item_Type                    0.017048
# Outlet_Location_Type         0.089367
# Outlet_Identifier            0.162325
# Outlet_Type                  0.401522
# Item_MRP                     0.567574
# Item_Outlet_Sales            1.000000
# Name: Item_Outlet_Sales, dtype: float64

# %% [markdown]
# - 1. Item_MRP is highly correlated with item_outlet_sales with 57%
# - 2. Outlet_type is also substantially correlated with item_outlet_sales with 40%
# - 3. Other features are not subtantially correlated with item_outlet_sales
# - 4. Item_Identifier has 0% correlation with item_outlet_sales so we remove it

# %%
#droping Item_Identifier feature
df.drop('Item_Identifier',axis=1,inplace=True)

# %%
#showing the dataframe after feature removal
df
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0           9.300                 1         0.016047          4  249.8092
# 1           5.920                 2         0.019278         14   48.2692
# 2          17.500                 1         0.016760         10  141.6180
# 3          19.200                 2         0.000000          6  182.0950
# 4           8.930                 1         0.000000          9   53.8614
# ...           ...               ...              ...        ...       ...
# 8518        6.865                 1         0.056783         13  214.5218
# 8519        8.380                 2         0.046982          0  108.1570
# 8520       10.600                 1         0.035186          8   85.1224
# 8521        7.210                 2         0.145221         13  103.1332
# 8522       14.800                 1         0.044878         14   75.4670
#
#       Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# ...

# %%
df.plot(kind='density', subplots=True, layout=(6,11), sharex=False, legend=False, fontsize=1, figsize=(18,12))
plt.show()

# %%
#Data Not normally distributed skeyness is present

# %%
df.plot(kind='hist', subplots=True, layout=(6,4), sharex=False, legend=False, fontsize=1, figsize=(18,12),title=list(df.columns))
plt.show()

# %%
df.plot(kind='box', subplots=True, layout=(4,4), sharex=False, legend=False, fontsize=1, figsize=(18,12),title=list(df.columns))
plt.show()

# %% [markdown]
# -Some outliers are present in Item_Identifier and in the target feature

# %% [markdown]
# # Descriptive Statistics

# %%
df.describe()
# Out:
#        Item_Weight  Item_Fat_Content  Item_Visibility    Item_Type  \
# count  8523.000000       8523.000000      8523.000000  8523.000000
# mean     12.857645          1.369354         0.066132     7.226681
# std       4.226124          0.644810         0.051598     4.209990
# min       4.555000          0.000000         0.000000     0.000000
# 25%       9.310000          1.000000         0.026989     4.000000
# 50%      12.857645          1.000000         0.053931     6.000000
# 75%      16.000000          2.000000         0.094585    10.000000
# max      21.350000          4.000000         0.328391    15.000000
#
#           Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# count  8523.000000        8523.000000                8523.000000  8523.000000
# mean    140.992782           4.722281                1997.831867     1.170832
# std      62.275067           2.837201                   8.371760     0.600327
# ...

# %% [markdown]
# - Features are not normally distributed

# %%
#showing describe elements using heatmap
import matplotlib.pyplot as plt
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=False,fmt='f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Summary")
plt.savefig('heatmap.png')
plt.show()

# %%
#showing columns data type and memory used by data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                8523 non-null   float64
#  1   Item_Fat_Content           8523 non-null   int32
#  2   Item_Visibility            8523 non-null   float64
#  3   Item_Type                  8523 non-null   int32
#  4   Item_MRP                   8523 non-null   float64
#  5   Outlet_Identifier          8523 non-null   int32
#  6   Outlet_Establishment_Year  8523 non-null   int64
#  7   Outlet_Size                8523 non-null   int32
#  8   Outlet_Location_Type       8523 non-null   int32
#  9   Outlet_Type                8523 non-null   int32
#  10  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int32(6), int64(1)
# memory usage: 532.8 KB

# %% [markdown]
# # Outliers Checking

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#Declaring variables 
collist=df.columns.values
ncol=25
nrow=15

# %%
collist
# Out:
# array(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Identifier', 'Outlet_Establishment_Year',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type',
#        'Item_Outlet_Sales'], dtype=object)

# %%
for i in range(0,len(collist)):
    print(collist[i])
# Out:
# Item_Weight
# Item_Fat_Content
# Item_Visibility
# Item_Type
# Item_MRP
# Outlet_Identifier
# Outlet_Establishment_Year
# Outlet_Size
# Outlet_Location_Type
# Outlet_Type
# Item_Outlet_Sales

# %%
#showing boxplot of features
plt.figure(figsize=(ncol,2*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(data=df[collist[i]],color='blue',orient='v')
    plt.tight_layout()

# %% [markdown]
# -  some outliers are present

# %% [markdown]
# # Skewness

# %%
#displaying skeness in the features of data frame
df.skew()
# Out:
# Item_Weight                  0.090561
# Item_Fat_Content             0.994824
# Item_Visibility              1.167091
# Item_Type                    0.101655
# Item_MRP                     0.127202
# Outlet_Identifier           -0.059861
# Outlet_Establishment_Year   -0.396641
# Outlet_Size                 -0.087072
# Outlet_Location_Type        -0.209093
# Outlet_Type                  0.927438
# Item_Outlet_Sales            1.177531
# dtype: float64

# %% [markdown]
# - Threshhold for skeness is +-0.7
# - some columns have higher skewness but they are encoded features so we will not change them
# - Target feature also has some skewness but we do not make any change to it

# %% [markdown]
# ## Removing outliers

# %%
#showing zscore of dataframe
from scipy.stats import zscore
np.abs(zscore(df))
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0        0.841872          0.572844         0.970732   0.766479  1.747454
# 1        1.641706          0.978092         0.908111   1.608963  1.489023
# 2        1.098554          0.572844         0.956917   0.658786  0.010040
# 3        1.500838          0.978092         1.281758   0.291391  0.660050
# 4        0.929428          0.572844         1.281758   0.421242  1.399220
# ...           ...               ...              ...        ...       ...
# 8518     1.418084          0.572844         0.181193   1.371418  1.180783
# 8519     1.059578          0.978092         0.371154   1.716656  0.527301
# 8520     0.534243          0.572844         0.599784   0.183698  0.897208
# 8521     1.336444          0.978092         1.532880   1.371418  0.607977
# 8522     0.459634          0.572844         0.411936   1.608963  1.052261
#
#       Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# ...

# %%
#showing shape of dataframe
z=np.abs(zscore(df))
z.shape
# Out:
# (8523, 11)

# %%
np.where(z>3)
# Out:
# (array([  49,   81,   83,  108,  130,  145,  151,  174,  199,  276,  304,
#          333,  339,  373,  396,  434,  456,  472,  489,  502,  521,  532,
#          615,  661,  694,  727,  753,  753,  809,  838,  854,  891,  935,
#          991,  997, 1009, 1010, 1034, 1090, 1124, 1133, 1138, 1159, 1183,
#         1209, 1254, 1272, 1291, 1311, 1324, 1372, 1433, 1434, 1450, 1496,
#         1501, 1506, 1512, 1542, 1549, 1560, 1575, 1576, 1615, 1617, 1644,
#         1651, 1684, 1723, 1753, 1769, 1805, 1827, 1841, 1859, 1998, 2062,
#         2088, 2109, 2111, 2122, 2143, 2168, 2173, 2216, 2223, 2238, 2251,
#         2293, 2324, 2331, 2438, 2439, 2445, 2516, 2535, 2552, 2569, 2586,
#         2613, 2660, 2678, 2728, 2776, 2855, 2895, 2905, 2971, 2973, 3011,
#         3017, 3083, 3087, 3098, 3154, 3206, 3225, 3234, 3241, 3242, 3243,
#         3286, 3335, 3367, 3399, 3407, 3458, 3474, 3480, 3488, 3491, 3497,
#         3509, 3540, 3545, 3582, 3602, 3667, 3709, 3720, 3750, 3757, 3767,
# ...

# %%
type(z)
# Out:
# pandas.core.frame.DataFrame

# %%
#43 rows have outliers
len(np.where(z>3)[0])
# Out:
# 302

# %%
df_new=df[(z<3).all(axis=1)]

# %% [markdown]
# ## Percentage Data Loss

# %%
print("Old Data Frame",df.shape)
print("New Data Frame",df_new.shape)
print("Total Data Loss",df.shape[0]-df_new.shape[0])
print("Loss %",302/8523*100)
# Out:
# Old Data Frame (8523, 11)
# New Data Frame (8222, 11)
# Total Data Loss 301
# Loss % 3.5433532793617273

# %% [markdown]
# - Since we have very less outliers so we will remove it as it will not affect the model much

# %%
#using df after removal of outliere
df=df_new
df
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0           9.300                 1         0.016047          4  249.8092
# 1           5.920                 2         0.019278         14   48.2692
# 2          17.500                 1         0.016760         10  141.6180
# 3          19.200                 2         0.000000          6  182.0950
# 4           8.930                 1         0.000000          9   53.8614
# ...           ...               ...              ...        ...       ...
# 8518        6.865                 1         0.056783         13  214.5218
# 8519        8.380                 2         0.046982          0  108.1570
# 8520       10.600                 1         0.035186          8   85.1224
# 8521        7.210                 2         0.145221         13  103.1332
# 8522       14.800                 1         0.044878         14   75.4670
#
#       Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# ...

# %%
#Dividing Data into features x and target y
y=pd.DataFrame(data=df.iloc[:,-1])
x=df.iloc[:,0:-1]

# %%
x
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0           9.300                 1         0.016047          4  249.8092
# 1           5.920                 2         0.019278         14   48.2692
# 2          17.500                 1         0.016760         10  141.6180
# 3          19.200                 2         0.000000          6  182.0950
# 4           8.930                 1         0.000000          9   53.8614
# ...           ...               ...              ...        ...       ...
# 8518        6.865                 1         0.056783         13  214.5218
# 8519        8.380                 2         0.046982          0  108.1570
# 8520       10.600                 1         0.035186          8   85.1224
# 8521        7.210                 2         0.145221         13  103.1332
# 8522       14.800                 1         0.044878         14   75.4670
#
#       Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# ...

# %%
y
# Out:
#       Item_Outlet_Sales
# 0             3735.1380
# 1              443.4228
# 2             2097.2700
# 3              732.3800
# 4              994.7052
# ...                 ...
# 8518          2778.3834
# 8519           549.2850
# 8520          1193.1136
# 8521          1845.5976
# 8522           765.6700
#
# [8222 rows x 1 columns]

# %% [markdown]
# # Transforming data to remove skewness

# %%
x.skew()
# Out:
# Item_Weight                  0.087821
# Item_Fat_Content             0.291106
# Item_Visibility              0.794506
# Item_Type                    0.094578
# Item_MRP                     0.139153
# Outlet_Identifier           -0.067611
# Outlet_Establishment_Year   -0.420927
# Outlet_Size                 -0.089519
# Outlet_Location_Type        -0.202794
# Outlet_Type                  0.957163
# dtype: float64

# %%
#we do not remove skewness as it is either in encoded feature or in target feature

# %% [markdown]
# #### Scaling the data

# %%
#from sklearn.preprocessing import MinMaxScaler
#mms=MinMaxScaler()

#x3=mms.fit_transform(x)
#x3=pd.DataFrame(data=x3)

# %%
#importing libraries
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error  #error checking system
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
#Showing best value of random state

lm=LinearRegression()
rstate=0
rscore=0

for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=i)
    lm.fit(x_train,y_train)
    pred=lm.predict(x_test)
    if(round(r2_score(y_test,pred)*100)>rscore):
        rstate=i
        rscore=round(r2_score(y_test,pred)*100)

print('best random state is',rstate," ",rscore)
# Out:
# best random state is 6   54

# %%
#splitting the data in train and test variables
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=54)

# %%
#checking the shape
x_train.shape
# Out:
# (6577, 10)

# %%
#checking the shape
y_train.shape
# Out:
# (6577, 1)

# %%
#checking the shape
x_test.shape
# Out:
# (1645, 10)

# %%
#checking the shape
y_test.shape
# Out:
# (1645, 1)

# %%
#instanciating LinearRegression 
lm=LinearRegression()
#Training the Machine
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#checking the coefficient
lm.coef_
# Out:
# array([[   -2.02182499,    54.44524631, -1034.01728831,    -1.50166984,
#            14.61837528,    60.52625569,     2.52300221,  -359.89268472,
#          -237.09151404,   809.83072053]])

# %%
#checking the intercept
lm.intercept_
# Out:
# array([-5494.89810039])

# %%
#showing the accuracy
lm.score(x_train,y_train)
# Out:
# 0.495521905572443

# %%
pred=lm.predict(x_test)

# %%
#printing predicted values
pred
# Out:
# array([[1919.57950792],
#        [1910.98573786],
#        [4012.07832067],
#        ...,
#        [2206.22988542],
#        [3231.82335509],
#        [ 535.36148581]])

# %%
#Printing Error value
print("Error :")

print("Mean Absolute Error = ",mean_absolute_error(y_test,pred))
print("mean squared error = ",mean_squared_error(y_test,pred))

print("root mean squared error = ",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# Error :
# Mean Absolute Error =  837.7102173528293
# mean squared error =  1181126.0169582292
# root mean squared error =  1086.7962168494282

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred)*100," %")
# Out:
# 51.23961636289221  %

# %%
from sklearn.model_selection import cross_val_score
src=cross_val_score(lm,x,y,cv=9)
print("Cross_val_score of LogisticRegression",src,"\n\n  mean ",src.mean())
# Out:
# Cross_val_score of LogisticRegression [0.51222748 0.51875086 0.48346204 0.48772674 0.49495406 0.50865559
#  0.47381178 0.49916491 0.49235878]
#
#   mean  0.49679024805099903

# %%
from sklearn.linear_model import Ridge
#instanciating Ridge 
rr=Ridge()
#Training the Machine
rr.fit(x_train,y_train)
pred=rr.predict(x_test)
print(" Score" ,rr.score(x_train,y_train))

print("\nr2 Score =",r2_score(y_test,pred)*100," %")
# Out:
#  Score 0.49551799333468793
#
# r2 Score = 51.23462648640197  %

# %%
from sklearn.model_selection import cross_val_score
src=cross_val_score(lm,x,y,cv=9)
print("Cross_val_score of Ridge",src,"\n\n  mean ",src.mean())
# Out:
# Cross_val_score of Ridge [0.51222748 0.51875086 0.48346204 0.48772674 0.49495406 0.50865559
#  0.47381178 0.49916491 0.49235878]
#
#   mean  0.49679024805099903

# %% [markdown]
# ### LogisticRegression is best as it has higher r2 score of 51 and least difference with cross validation score 49

# %% [markdown]
# ##### hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

parameters = {'copy_X':[True,False], 'positive':[True,False]}

lr=LinearRegression()

clf = GridSearchCV(lr,parameters,cv=7,scoring='accuracy')
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'copy_X': True, 'positive': True}

# %% [markdown]
# #### Final Training of model

# %%
lr=LinearRegression(copy_X=True,positive=True)
lr.fit(x_train,y_train)
pred=lr.predict(x_test)
print(" Score" ,lr.score(x_train,y_train))

print("\nr2 Score =",r2_score(y_test,pred)*100," %")
# Out:
#  Score 0.4828250366147735
#
# r2 Score = 50.11404747266408  %

# %% [markdown]
# #### r2 score is 50%

# %%
#using the model
lm.predict([[1,4,5,6,7,8,6,2,1,22]])
# Out:
# array([[7002.84025329]])

# %%
#saving the model
import pickle
outfile=open('mylr.obj','wb')
pickle.dump(lm,outfile)
outfile.close()

# %%
#loading the model
infile=open('mylr.obj','rb')
new_lm=pickle.load(infile)
infile.close()

# %%
#using the model
new_lm.predict([[1,4,5,6,7,8,6,2,1,22]])
# Out:
# array([[7002.84025329]])

# %% [markdown]
# ##### The test dataframe can be used for testing and the r2 score can be improved but due to shortage of time both could not be done
# ##### The process would be the same.
